# %% [markdown]
# <a href="https://colab.research.google.com/github/NaiLopes-br/FlorescerMIA/blob/main/FlorescerMIA_Prot%C3%B3tipo_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Kivy with the 'full' extra to include optional components like webview
# %pip install kivy[full]

# Restart the kernel first (This action needs to be done manually in the notebook interface)
# Then, run the installation cell again.

# Install Kivy with the 'full' extra to include optional components like webview
# We use the same command as before, but ensure a clean state by restarting the kernel.
# If this still fails, consider adding '-U --no-cache-dir' to force a fresh install
# %pip install kivy[full] -U --no-cache-dir

# %%
# After successfully installing and restarting the kernel, run this cell.
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.properties import StringProperty
from kivy.core.window import Window
from kivy.uix.boxlayout import BoxLayout
from kivy.utils import get_color_from_hex

class TelaRecuperacao(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.orientation = 'vertical'
        self.padding = 20

        # Define as cores que você solicitou
        cor_principal = get_color_from_hex('#8bff89')
        cor_secundaria = get_color_from_hex('#ff8697')
        cor_terciaria = get_color_from_hex('#4ec9ff')
        cor_branco = get_color_from_hex('#ffffff')

        # Carrega o conteúdo do seu arquivo HTML
        try:
            with open('recuperacao_senha.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

        # Cria o WebView para exibir o conteúdo HTML
        self.webview = WebView(html=self.html_content)
        self.add_widget(self.webview)

class RecuperacaoSenhaApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0') # Cor de fundo do aplicativo
        return TelaRecuperacao()

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout

from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.uix.image import Image

class TelaCriarConta(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.orientation = 'vertical'
        self.padding = 20

        # Adiciona a logo como um widget Kivy
        self.logo = Image(source='logo.png', size_hint_y=None, height=100) # Ajuste o 'height' conforme necessário
        self.add_widget(self.logo)

        # Carrega o conteúdo do arquivo HTML de criar conta
        try:
            with open('criar_conta.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

        # Cria o WebView para exibir o conteúdo HTML
        self.webview = WebView(html=self.html_content)
        self.add_widget(self.webview)

class CriarContaApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaCriarConta()

    def on_start(self):
        # Certifique-se de que o arquivo da logo 'logo.png' esteja na mesma pasta
        # ou ajuste o 'source' do Image widget para o caminho correto.
        pass

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout
from kivy.properties import StringProperty
from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.lang import Builder
from kivy.uix.image import Image

class TelaRecuperacao(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('recuperacao_senha.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class RecuperacaoSenhaApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaRecuperacao()

class TelaCriarConta(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('criar_conta.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class CriarContaApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaCriarConta()

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout
from kivy.properties import StringProperty
from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.lang import Builder

class TelaLogin(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('telalogin.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class LoginApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaLogin()

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout
from kivy.properties import StringProperty
from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.lang import Builder

class TelaMia(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('telamia.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class MiaApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaMia()

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout
from kivy.properties import StringProperty
from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.lang import Builder

class TelaMiaAi(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('telamiaai.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class MiaAiApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaMiaAi()

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout
from kivy.properties import StringProperty
from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.lang import Builder

class TelaConfiguracoes(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('telaconfiguracoes.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class ConfiguracoesApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaConfiguracoes()

# %%
from kivy.app import App
from kivy.uix.boxlayout import BoxLayout
from kivy.properties import StringProperty
from kivy.utils import get_color_from_hex
from kivy.core.window import Window
from kivy.lang import Builder

class TelaPlataforma(BoxLayout):
    html_content = StringProperty('')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        try:
            with open('telaplataforma.html', 'r', encoding='utf-8') as f:
                self.html_content = f.read()
        except FileNotFoundError:
            self.html_content = '<h1>Arquivo HTML não encontrado!</h1>'

class PlataformaApp(App):
    def build(self):
        Window.clearcolor = get_color_from_hex('#f0f0f0')
        return TelaPlataforma()
